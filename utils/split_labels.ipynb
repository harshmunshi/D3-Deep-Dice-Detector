# %%
import numpy as np
import pandas as pd
np.random.seed(1)

# %%
full_labels = pd.read_csv('./dice_dataset/data/dice_labels.csv')

# %%
full_labels
# Out:
#                     filename  width  height      class  xmin  ymin  xmax  ymax
# 0    2018-10-08@15-51-36.png   1936    1216          6   915   455   987   540
# 1    2018-10-08@15-51-36.png   1936    1216          2  1011   434  1085   521
# 2    2018-10-08@15-51-36.png   1936    1216          3   437   625   530   714
# 3    2018-10-08@15-51-36.png   1936    1216          6   506   697   585   771
# 4    2018-10-08@15-51-36.png   1936    1216          3   613   810   719   901
# 5    2018-10-08@15-51-36.png   1936    1216          2   861   610   941   705
# 6    2018-10-08@15-51-36.png   1936    1216  sugarcube   861  1095   913  1160
# 7    2018-10-08@16-28-46.png   1936    1216          2   513   595   604   684
# 8    2018-10-08@16-28-46.png   1936    1216          4   798   597   891   688
# 9    2018-10-08@16-28-46.png   1936    1216          5   780   371   850   460
# 10   2018-10-08@16-28-46.png   1936    1216          1   993   351  1074   440
# ...

# %%
grouped = full_labels.groupby('filename')

# %%
grouped.apply(lambda x: len(x)).value_counts()
# Out:
# 6     8
# 5     4
# 7     3
# 4     3
# 10    1
# 3     1
# dtype: int64

# %%
gb = full_labels.groupby('filename')

# %%
grouped_list = [gb.get_group(x) for x in gb.groups]

# %%
len(grouped_list)
# Out:
# 20

# %%
train_index = np.random.choice(len(grouped_list), size=16, replace=False)
test_index = np.setdiff1d(list(range(20)), train_index)

# %%
len(train_index), len(test_index)
# Out:
# (16, 4)

# %%
train = pd.concat([grouped_list[i] for i in train_index])
test = pd.concat([grouped_list[i] for i in test_index])

# %%
len(train), len(test)
# Out:
# (91, 23)

# %%
train.to_csv('train_labels.csv', index=None)
test.to_csv('test_labels.csv', index=None)
